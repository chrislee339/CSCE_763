# %%
import pandas as pd
from PIL import Image

from imgaug import augmenters as iaa
import imageio
import numpy as np
import os
from imgaug.augmentables.kps import KeypointsOnImage, Keypoint

import cv2
from pathlib import Path

# %%
### Divide image into quadrants, keeping track of kinetoplast and nucleus
data = pd.read_csv('/Users/clee/Documents/Nolan_Lab/chagas/peerj-10-13470-s001_all.csv')

pos_dir = '/Users/clee/Documents/Nolan_Lab/chagas/split_images/positive_images'
neg_dir = '/Users/clee/Documents/Nolan_Lab/chagas/split_images/negative_images'

def is_in_quadrant(x, y, quad, width, height):
    if quad == 1:
        return x < width // 2 and y < height // 2
    elif quad == 2:
        return x >= width // 2 and y < height // 2
    elif quad == 3:
        return x < width // 2 and y >= height // 2
    elif quad == 4:
        return x >= width // 2 and y >= height // 2
    
def process_image(image_name, data, pos_dir, neg_dir):
    image_path = f'/Users/clee/Documents/Nolan_Lab/chagas/all/{image_name}'  
    with Image.open(image_path) as img:
        width, height = img.size

        quadrants = {
            1: img.crop((0, 0, width // 2, height // 2)),
            2: img.crop((width // 2, 0, width, height // 2)),
            3: img.crop((0, height // 2, width // 2, height)),
            4: img.crop((width // 2, height // 2, width, height))
        }

        # Check if quadrant contains t.cruzi
        quad_contains_tcruzi = {i: False for i in quadrants}

        for index, row in data[data['filename'] == image_name].iterrows():
            for quad in quadrants:
                if is_in_quadrant(row['x'], row['y'], quad, width, height):
                    quad_contains_tcruzi[quad] = True

        for quad, image in quadrants.items():
            image_filename = f'{image_name.split(".")[0]}_quad{quad}.jpg'
            image_save_path = f'{pos_dir}/{image_filename}' if quad_contains_tcruzi[quad] else f'{neg_dir}/{image_filename}'
            image.save(image_save_path)

# Process each image in the dataset
image_files = [f"field{str(i).zfill(4)}.jpg" for i in range(1, 705)]  

for image_name in image_files:
    try:
        process_image(image_name, data, pos_dir, neg_dir)
    except FileNotFoundError:
        print(f"Image {image_name} not found. Skipping...")

positive_images = os.listdir(pos_dir)
negative_images = os.listdir(neg_dir)
print("Positive images:", positive_images)
print("Negative images:", negative_images)
# Out:
# Image field0002.jpg not found. Skipping...
# Image field0003.jpg not found. Skipping...
# Image field0013.jpg not found. Skipping...
# Image field0026.jpg not found. Skipping...
# Image field0031.jpg not found. Skipping...
# Image field0059.jpg not found. Skipping...
# Image field0063.jpg not found. Skipping...
# Image field0126.jpg not found. Skipping...
# Image field0156.jpg not found. Skipping...
# Image field0180.jpg not found. Skipping...
# Image field0246.jpg not found. Skipping...
# Image field0254.jpg not found. Skipping...
# Image field0289.jpg not found. Skipping...
# Image field0308.jpg not found. Skipping...
# Image field0327.jpg not found. Skipping...
# Image field0337.jpg not found. Skipping...
# Image field0352.jpg not found. Skipping...
# Image field0361.jpg not found. Skipping...
# Image field0402.jpg not found. Skipping...
# Image field0447.jpg not found. Skipping...
# Image field0451.jpg not found. Skipping...
# Image field0455.jpg not found. Skipping...
# Image field0462.jpg not found. Skipping...
'field0058_quad4.jpg', 'field0030_quad3.jpg', 'field0328_quad4.jpg', 'field0206_quad3.jpg', 'field0434_quad4.jpg', 'field0420_quad4.jpg', 'field0302_quad1.jpg', 'field0616_quad4.jpg', 'field0280_quad2.jpg', 'field0139_quad2.jpg', 'field0413_quad2.jpg', 'field0522_quad1.jpg', 'field0008_quad1.jpg', 'field0493_quad4.jpg', 'field0652_quad1.jpg', 'field0378_quad1.jpg', 'field0346_quad4.jpg', 'field0696_quad2.jpg', 'field0469_quad2.jpg', 'field0115_quad1.jpg', 'field0053_quad1.jpg', 'field0547_quad4.jpg', 'field0097_quad2.jpg', 'field0268_quad2.jpg', 'field0118_quad2.jpg', 'field0604_quad2.jpg', 'field0221_quad4.jpg', 'field0555_quad3.jpg', 'field0390_quad1.jpg', 'field0151_quad4.jpg', 'field0448_quad2.jpg', 'field0354_quad2.jpg', 'field0206_quad2.jpg', 'field0030_quad2.jpg', 'field0389_quad2.jpg', 'field0340_quad2.jpg', 'field0176_quad2.jpg', 'field0667_quad1.jpg', 'field0384_quad1.jpg', 'field0659_quad4.jpg', 'field0529_quad4.jpg', 'field0083_quad2.jpg', 'field0560_quad2.jpg', 'fi ...

# %%
### Augment Negative images
# Blacken areas due to rotation
def blacken(image, threshold=500):
    gray_image = np.mean(image, axis=2)
    mask = gray_image > threshold
    image[mask] = [0, 0, 0] 
    return image

def augment_negative_image(image_path, seq, output_directory, filename, aug_count):
    image = imageio.imread(image_path)

    for i in range(aug_count):

        seq_det = seq.to_deterministic()
        image_aug = seq_det(image=image)
        image_aug = blacken(image_aug)

        save_path = os.path.join(output_directory, 'negative_images', f"{os.path.splitext(filename)[0]}_augmented_{i}.png")
        imageio.imwrite(save_path, image_aug)

# Augmentations
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Flipud(0.2), 
    iaa.Affine(
        rotate=(-160, 160),  
        scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},  
        translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)}, 
        shear=(-5, 5), 
        cval=0  
    )
], random_order=True)  

input_directory = '/Users/clee/Documents/Nolan_Lab/chagas/split_images/negative_images'
output_directory = '/Users/clee/Documents/Nolan_Lab/chagas/split_images/augmented_images'
        
aug_count = 2

for filename in os.listdir(input_directory):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_directory, filename)
        augment_negative_image(image_path, seq, output_directory, filename, aug_count)
# Out:
# /var/folders/1f/_308mdp92hd4dnhtd2p2jgk40000gn/T/ipykernel_30024/3349561197.py:24: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)

# %%
### Standardize - Rescale images to 1224x1632 & convert to png
def resize_and_convert_image(image_path, output_size, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    with Image.open(image_path) as img:

        if img.mode != 'RGB':
            img = img.convert('RGB')

        img = img.resize(output_size, Image.ANTIALIAS)

        output_file_path = os.path.join(output_dir, os.path.splitext(os.path.basename(image_path))[0] + '.png')
        
        img.save(output_file_path, 'PNG')
        print(f'Saved: {output_file_path}')

def process_directory(input_dir, output_dir, output_size):
    for subdir, dirs, files in os.walk(input_dir):
        for file in files:
            filepath = os.path.join(subdir, file)
            if filepath.lower().endswith(('.png', '.jpg', '.jpeg')):
                relative_path = os.path.relpath(subdir, input_dir)
                new_output_dir = os.path.join(output_dir, relative_path)
                
                resize_and_convert_image(filepath, output_size, new_output_dir)

desired_size = (1224, 1632)

base_input_directory = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/original'
base_output_directory = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed' 

process_directory(base_input_directory, base_output_directory, desired_size)
# Out:
# /var/folders/1f/_308mdp92hd4dnhtd2p2jgk40000gn/T/ipykernel_22128/1814627719.py:13: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(output_size, Image.ANTIALIAS)
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0443_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0553_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0079_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0157_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0286_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0396_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0675_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0415_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0227_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0219_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0309_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0011_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0508_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0214_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0164_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0678_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0145_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0690_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0373_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0631_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0113_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0439_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0529_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0407_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0235_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0325_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0091_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0221_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0331_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0139_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0107_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0017_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0625_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0277_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0367_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0684_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0249_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0198_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0151_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0346_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0036_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0005_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0233_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0401_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0511_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0382_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0143_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0469_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0547_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0375_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0547_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0292_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0401_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0637_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0036_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0432_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0118_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0310_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0200_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0060_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0170_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0493_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0256_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0097_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0574_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0198_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0684_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0367_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0420_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0212_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0616_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0024_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0354_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0566_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0085_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0448_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0162_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0654_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0176_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0495_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0091_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0389_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0340_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0030_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0602_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0238_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0206_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0524_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0434_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0235_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0529_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0659_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0560_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0083_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0678_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0242_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0597_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0074_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0487_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0164_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0304_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0214_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0022_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0508_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0418_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0132_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0623_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0415_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0286_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0079_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0553_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0675_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0169_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0214_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0304_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0700_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0132_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0418_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0508_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0022_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0242_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0678_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0193_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0470_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0164_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0487_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0074_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0597_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0646_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0263_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0439_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0238_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0328_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0434_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0585_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0066_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0654_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0148_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0181_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0572_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0091_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0058_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0195_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0476_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0085_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0689_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0072_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0628_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0530_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0134_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0616_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0107_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0041_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0652_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0493_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0170_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0583_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0060_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0464_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0187_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0256_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0346_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0036_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0310_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0511_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0661_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0382_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0053_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0547_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0457_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0637_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0115_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0511_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0323_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0310_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0256_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0583_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0684_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0445_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0041_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0151_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0198_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0359_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0029_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0331_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0017_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0530_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0689_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0476_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0181_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0654_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0238_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0529_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0113_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0325_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0517_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0667_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0055_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0690_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0659_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0263_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0074_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0132_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0505_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0415_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0101_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0219_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0079_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0443_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0169_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0271_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0675_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0286_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0047_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0011_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0470_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0193_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0560_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0646_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0487_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0164_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0426_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0536_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0700_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0610_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0588_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0541_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0176_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0495_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0066_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0585_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0091_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0572_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0299_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0250_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0340_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0389_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0120_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0602_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0316_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0212_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0628_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0134_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0024_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0244_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0354_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0566_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0085_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0162_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0448_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0558_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0591_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0072_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0249_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0555_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0625_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0604_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0036_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0118_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0432_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0200_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0170_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0268_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0187_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0464_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0097_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0574_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0375_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0143_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0233_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0005_quad2.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0005_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0637_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0323_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0609_quad1.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0233_quad3.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field0401_quad4.png
# Saved: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/positive_images/field
/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed/negative_images/field0326_quad4.png

# %%
### White balance images
def white_balance(img):
    wb = cv2.xphoto.createSimpleWB()
    wb.setP(0.5)
    balanced_img = wb.balanceWhite(img)
    return balanced_img

def process_images(source_directory, target_directory):
    os.makedirs(target_directory, exist_ok=True)
    
    for subdir, dirs, files in os.walk(source_directory):
        for file in files:
            filepath = os.path.join(subdir, file)
            if filepath.lower().endswith(('.png', '.jpg', '.jpeg')):
                img = cv2.imread(filepath)
                if img is not None:
                    img_balanced = white_balance(img)
                    relative_path = os.path.relpath(subdir, source_directory)
                    target_subdir = os.path.join(target_directory, relative_path)
                    os.makedirs(target_subdir, exist_ok=True)
                    output_file_path = os.path.join(target_subdir, file)
                    cv2.imwrite(output_file_path, img_balanced)
                    print(f"Processed and saved white-balanced image: {output_file_path}")
                else:
                    print(f"Failed to read image: {filepath}")

source_directory = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed'
target_directory = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance'

process_images(source_directory, target_directory)
# Out:
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0379_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0578_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0052_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0608_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0322_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0686_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0223_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0614_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0704_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0210_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0532_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0422_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0108_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0278_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0483_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0564_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0087_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0474_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0197_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0356_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0545_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0403_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0129_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0202_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0430_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0034_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0124_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0606_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0095_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0344_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0062_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0458_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0172_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0595_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0076_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0485_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0166_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0350_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0240_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0048_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0562_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0081_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0612_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0020_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0130_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0424_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0216_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0621_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0342_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0668_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0093_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0570_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0183_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0460_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0497_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0656_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0526_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0436_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0204_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0600_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0032_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0001_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0147_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0692_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0069_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0261_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0371_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0296_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0147_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0057_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0237_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0405_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0111_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0001_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0633_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0600_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0436_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0570_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0284_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0394_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0488_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0598_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0551_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0363_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0680_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0539_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0621_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0417_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0507_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0216_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0020_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0399_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0166_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0172_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0458_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0034_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0202_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0129_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0403_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0513_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0635_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0545_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0188_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0141_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0259_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0290_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0564_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0278_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0108_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0627_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0015_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0223_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0153_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0569_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0043_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0365_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0686_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0043_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0153_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0686_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0275_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0105_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0619_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0501_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0704_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0474_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0197_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0349_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0380_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0663_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0051_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0321_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0039_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0513_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0403_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0129_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0117_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0635_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0124_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0312_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0638_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0548_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0240_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0130_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0621_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0429_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0507_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0417_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0045_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0677_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0394_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0273_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0551_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0488_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0441_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0515_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0237_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0209_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0001_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0111_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0692_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0261_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0453_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0179_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0057_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0147_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0057_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0261_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0526_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0122_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0408_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0600_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0183_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0570_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0252_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0656_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0587_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0064_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0441_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0677_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0507_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0130_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0020_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0702_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0216_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0306_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0534_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0644_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0158_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0191_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0240_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0350_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0344_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0466_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0185_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0491_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0172_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0548_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0062_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0650_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0202_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0638_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0312_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0034_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0380_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0070_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0278_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0642_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0368_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0197_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0474_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0087_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0564_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0704_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0614_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0136_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0108_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0422_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0532_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0018_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0300_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0105_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0043_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0627_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0501_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0411_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0223_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0153_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0392_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0671_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0282_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0365_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0686_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0557_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0160_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0483_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0403_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0129_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0007_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0117_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0694_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0377_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0267_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0545_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0098_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0051_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0188_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0259_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0095_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0606_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0430_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0612_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0048_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0284_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0045_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0551_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0363_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0680_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0649_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0539_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0429_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0103_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0225_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0032_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0204_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0174_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0342_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0668_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0069_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0543_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0179_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0371_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0386_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0296_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0147_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0237_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0515_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0633_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0209_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0319_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0405_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0296_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0543_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0252_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0668_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0342_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0093_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0174_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0497_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0064_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0204_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0314_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0122_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0032_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0649_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0680_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0644_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0399_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0158_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0191_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0562_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0081_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0048_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0702_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0612_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0338_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0020_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0424_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0202_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0430_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0520_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0034_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0095_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0576_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images/field0699_quad1.png
# ...
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0173_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0241_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0307_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0210_quad1_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0472_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0460_quad4_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0428_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0272_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0422_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0044_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0044_quad3_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0343_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0695_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0657_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0175_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0033_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0070_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0612_quad1_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0062_quad4_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0387_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0452_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0178_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0393_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0593_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0300_quad3_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0643_quad3_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0348_quad4_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0533_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0538_quad1_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0482_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0071_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0326_quad4_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0556_quad1_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0275_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0191_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0050_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0116_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0320_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0313_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0639_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0490_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0255_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0577_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0549_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0698_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0651_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0184_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0467_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0490_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0230_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0038_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0376_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0695_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0275_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0348_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0099_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0191_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0140_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0326_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0247_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0556_quad1_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0592_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0071_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0348_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0538_quad1_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0643_quad3_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0500_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0300_quad3_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0593_quad2_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0556_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0260_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0542_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0297_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0612_quad1_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0404_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0070_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0326_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0062_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0632_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0318_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0110_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0123_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0315_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0586_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0044_quad3_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0695_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0253_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0422_quad4_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0044_quad3.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0395_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0440_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0538_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0472_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0506_quad4.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0210_quad1_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0460_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0224_quad1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0173_quad2_augmented_1.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0285_quad4_augmented_0.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0159_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0473_quad2.png
# Processed and saved white-balanced image: /Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images/field0645_quad2.png

# %%
### Count number of quadrants
def count_quadrants(directory):
    quad_counts = {'quad1': 0, 'quad2': 0, 'quad3': 0, 'quad4': 0}
    total_files = 0

    files = os.listdir(directory)

    for filename in files:
        if filename.endswith('.png'):
            total_files += 1  
            if 'quad1' in filename:
                quad_counts['quad1'] += 1
            elif 'quad2' in filename:
                quad_counts['quad2'] += 1
            elif 'quad3' in filename:
                quad_counts['quad3'] += 1
            elif 'quad4' in filename:
                quad_counts['quad4'] += 1

    if total_files == 0:
        return quad_counts, {quad: 0 for quad in quad_counts}

    quad_percentages = {quad: (count / total_files) * 100 for quad, count in quad_counts.items()}

    return quad_counts, quad_percentages

#directory_path = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/positive_images'
directory_path = '/Users/clee/Documents/Nolan_Lab/chagas/test_images/processed_whitebalance/negative_images'

quad_counts, quad_percentages = count_quadrants(directory_path)

print("Counts:")
for quad, count in quad_counts.items():
    print(f"{quad}: {count}")
print("Percentages:")
for quad, percentage in quad_percentages.items():
    print(f"{quad}: {percentage:.2f}%")
# Out:
# Counts:
# quad1: 428
# quad2: 622
# quad3: 209
# quad4: 486
# Percentages:
# quad1: 24.53%
# quad2: 35.64%
# quad3: 11.98%
# quad4: 27.85%
